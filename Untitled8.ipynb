# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sl

# %%
data=pd.read_csv("data.csv")
data
# Out:
#     EmpId EmpName  joinYear  B_Salary       TA     DA     Total
# 0   12345  Deepak      2000   20020.0  1001.00  24.00  21045.00
# 1   12346    Raju      2023   20030.0  1001.50  60.00  21091.50
# 2   12347   Mohan      2022   21000.0  1050.00  65.00  22115.00
# 3   12348   Shyam      2008   22000.0  1100.00  60.00  23160.00
# 4   12349  Dinesh      2006   22490.0  1124.50  60.69  23675.19
# ..    ...     ...       ...       ...      ...    ...       ...
# 94  12439   Shyam      2016   84680.0  4234.00  60.48  88974.48
# 95  12440  Dinesh      2016   85371.0  4268.55  60.48  89700.03
# 96  12441   Rahul      2016   86062.0  4303.10  60.48  90425.58
# 97  12442   Mohit      2016       NaN      NaN    NaN       NaN
# 98  12443  Deepak      2016   87444.0  4372.20  60.48  91876.68
#
# [99 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# EmpId        0
# EmpName      0
# joinYear     0
# B_Salary    10
# TA          10
# DA           2
# Total        5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# EmpId       0
# EmpName     0
# joinYear    0
# B_Salary    0
# TA          0
# DA          0
# Total       0
# dtype: int64

# %%
sl.displot(data["B_Salary"])
plt.show()

# %%
ms=MinMaxScaler()

# %%
ms.fit(data[["B_Salary"]])
# Out:
# MinMaxScaler()

# %%
data["New_minmax"]=pd.DataFrame(ms.transform(data[["B_Salary"]]),columns=["X"])

# %%
data.head()
# Out:
#    EmpId EmpName  joinYear  B_Salary      TA     DA     Total  New_minmax
# 0  12345  Deepak      2000   20020.0  1001.0  24.00  21045.00    0.000000
# 1  12346    Raju      2023   20030.0  1001.5  60.00  21091.50    0.000148
# 2  12347   Mohan      2022   21000.0  1050.0  65.00  22115.00    0.014535
# 3  12348   Shyam      2008   22000.0  1100.0  60.00  23160.00    0.029366
# 4  12349  Dinesh      2006   22490.0  1124.5  60.69  23675.19    0.036634

# %%
sl.displot(data["New_minmax"])
sl.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 sl.displot(data["New_minmax"])
# ----> 2 sl.plot()
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
data.shape
# Out:
# (89, 8)
